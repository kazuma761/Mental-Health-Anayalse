# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Dropout, Flatten
import tensorflow as tf
import pickle

# Load the dataset
df = pd.read_csv('merged_output.csv')

# Load positive and depressed words
with open('positive-words.txt', 'r') as file:
    positive_words = set(file.read().splitlines())

with open('depressedword.txt', 'r') as file:
    depressed_words = set(file.read().splitlines())

# Function to label the sentiment
def label_sentiment(text):
    words = set(text.lower().split())
    positive_count = len(words.intersection(positive_words))
    depressed_count = len(words.intersection(depressed_words))
    
    if depressed_count > positive_count:
        return 2  # Depressed
    elif positive_count > 0:
        return 1  # Positive
    else:
        return 0  # Neutral/Negative

# Create labels based on word counts
df['label'] = df['content'].apply(label_sentiment)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(df['content'], df['label'], test_size=0.2, random_state=42)

# Tokenize the text
max_words = 670000
max_len = 200

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X_train)

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

X_train_pad = pad_sequences(X_train_seq, maxlen=max_len)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len)

# Encode labels
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# Convert to categorical
y_train_cat = tf.keras.utils.to_categorical(y_train_encoded, num_classes=3)
y_test_cat = tf.keras.utils.to_categorical(y_test_encoded, num_classes=3)

# Define the Simple Neural Network model
embedding_dim = 200

model = Sequential([
    Embedding(max_words, embedding_dim, input_length=max_len),
    Flatten(),  # Flatten the output from the embedding layer
    Dense(128, activation='relu'),  # First dense layer
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(64, activation='relu'),   # Second dense layer
    Dropout(0.5),  # Another dropout layer
    Dense(3, activation='softmax')  # Output layer for 3 classes
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
print(model.summary())

# Train the model
model.fit(X_train_pad, y_train_cat, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/4
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices to a dense Tensor with 134000000 elements. This may consume a large amount of memory.
#   warnings.warn(
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 84s 242ms/step - accuracy: 0.5816 - loss: 0.9290 - val_accuracy: 0.8132 - val_loss: 0.4955
# Epoch 2/4
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 89s 259ms/step - accuracy: 0.8149 - loss: 0.5173 - val_accuracy: 0.8461 - val_loss: 0.3866
# Epoch 3/4
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 92s 270ms/step - accuracy: 0.8754 - loss: 0.3197 - val_accuracy: 0.8710 - val_loss: 0.3487
# Epoch 4/4
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 92s 270ms/step - accuracy: 0.9013 - loss: 0.2431 - val_accuracy: 0.8615 - val_loss: 0.4056

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Dropout, Flatten
import tensorflow as tf
import pickle

# Load the dataset
df = pd.read_csv('merged_output.csv')

# Load positive and depressed words
with open('positive-words.txt', 'r') as file:
    positive_words = set(file.read().splitlines())

with open('depressedword.txt', 'r') as file:
    depressed_words = set(file.read().splitlines())

# Function to label the sentiment
def label_sentiment(text):
    words = set(text.lower().split())
    positive_count = len(words.intersection(positive_words))
    depressed_count = len(words.intersection(depressed_words))
    
    # Debugging output
    print(f"Text: {text}, Positive Count: {positive_count}, Depressed Count: {depressed_count}")
    
    if depressed_count > positive_count:
        return 2  # Depressed
    elif positive_count > 0:
        return 1  # Positive
    else:
        return 0  # Neutral/Negative

# Create labels based on word counts
df['label'] = df['content'].apply(label_sentiment)

# Check class distribution
print("\nLabel Distribution:")
print(df['label'].value_counts())

# Split the data
X_train, X_test, y_train, y_test = train_test_split(df['content'], df['label'], test_size=0.2, random_state=42)

# Tokenize the text
max_words = 670000
max_len = 200

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X_train)

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

X_train_pad = pad_sequences(X_train_seq, maxlen=max_len)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len)

# Encode labels
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# Convert to categorical
y_train_cat = tf.keras.utils.to_categorical(y_train_encoded, num_classes=3)
y_test_cat = tf.keras.utils.to_categorical(y_test_encoded, num_classes=3)
# Out:
# Text: thank you, Positive Count: 1, Depressed Count: 0
# Text: mmm k, Positive Count: 0, Depressed Count: 0
# Text: i'm doing good thank you, Positive Count: 2, Depressed Count: 0
# Text: i'm from los angeles, Positive Count: 0, Depressed Count: 0
# Text: oh great, Positive Count: 1, Depressed Count: 0
# Text: i live in west los angeles the west side, Positive Count: 0, Depressed Count: 0
# Text: it's alright, Positive Count: 0, Depressed Count: 0
# Text: i xxx, Positive Count: 0, Depressed Count: 0
# Text: no i live alone so, Positive Count: 0, Depressed Count: 1
# Text: i love it i'm from here so i grew up here it's natural, Positive Count: 1, Depressed Count: 0
# Text: the weather um well the weather, Positive Count: 1, Depressed Count: 0
# Text: it's always good it's never it's never bad uh um there's always something to do it's rarely a dull moment, Positive Count: 1, Depressed Count: 2
# Text: the traffic, Positive Count: 0, Depressed Count: 0
# Text: the traffic is horrible well probably traffic is horrible in almost any major city but i hate the traffic, Positive Count: 1, Depressed Count: 2
# Text: not really i mean i have enough things going on here so if i travel it's usually somewhere that's within driving distance, Positive Count: 1, Depressed Count: 0
# Text: i studied uh business, Positive Count: 0, Depressed Count: 0
# Text: i did, Positive Count: 0, Depressed Count: 0
# Text: no i've i've been done for a few years so i haven't gone to school for a while, Positive Count: 0, Depressed Count: 0
# Text: one of these days i'll go back to graduate school but, Positive Count: 0, Depressed Count: 0
# Text: my dream job would be to just work for myself and making lots of money um, Positive Count: 1, Depressed Count: 0
# Text: i don't know i don't really have a dream job just something that i can, Positive Count: 0, Depressed Count: 0
# Text: i can work under my own terms and get paid decently and and be in a creative creative environment, Positive Count: 2, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: i don't know i think it's just a matter of finding the right situation so right now eh it's been people are a little conservative about what they want so and how they want it so it's a little tougher than it seems <se> it should be but i don't know i think when the situation's right i don't think it's too difficult, Positive Count: 2, Depressed Count: 2
# Text: yep, Positive Count: 0, Depressed Count: 0
# Text: i work as an assistant <as> administrative assistant through a temp agency so, Positive Count: 1, Depressed Count: 0
# Text: it's just basically i get sent out to do uh, Positive Count: 0, Depressed Count: 0
# Text: to do desk jobs , Positive Count: 0, Depressed Count: 0
# Text: um yes and no i mean i feel like i feel like i could do more but you know it works so , Positive Count: 2, Depressed Count: 0
# Text: you know yeah, Positive Count: 0, Depressed Count: 0
# Text: i'm pretty close i mean they're around so, Positive Count: 1, Depressed Count: 0
# Text: um god really mad, Positive Count: 0, Depressed Count: 1
# Text: stupid people just basically doing just doing anything to annoy me, Positive Count: 0, Depressed Count: 2
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: that's basically <ba> that's the big thing just just irritating stupid people <laughter> who just do things just to provoke provoke me for no reason at all, Positive Count: 0, Depressed Count: 3
# Text: um what's a good example, Positive Count: 1, Depressed Count: 0
# Text: just random people who who think it's funny to just sit there and get a rise out of me just it doesn't have to be one any specific, Positive Count: 0, Depressed Count: 1
# Text: situation it's just people who just think it's funny to i think they're just generally sadistic and they just think it's it's funny to to just prod you like it's like poking a stick at an angry dog knowing that they know how to they just wanna push your buttons for no reason so, Positive Count: 1, Depressed Count: 2
# Text: uh god, Positive Count: 0, Depressed Count: 0
# Text: i don't remember i with those situations i usually try not to remember <laughter> when when it happens i just i just let it go and just like the past is the past i just tend not to look back, Positive Count: 1, Depressed Count: 0
# Text: what do you mean, Positive Count: 0, Depressed Count: 0
# Text: okay, Positive Count: 0, Depressed Count: 0
# Text: god what do i do to relax i like to run i like to go to the gym, Positive Count: 1, Depressed Count: 0
# Text: listen to music i have a lot of musician friends so i just so i'm usually around musicians so, Positive Count: 0, Depressed Count: 0
# Text: anything of that sort i like, Positive Count: 1, Depressed Count: 0
# Text: i like everything from punk rock art to tattoos to just anything that's that's generally art and creative, Positive Count: 2, Depressed Count: 1
# Text: who's been a positive <pos>, Positive Count: 1, Depressed Count: 0
# Text: i think it's just friends in general who who seem to who seem to do well and i think they they're very inspiring and, Positive Count: 2, Depressed Count: 0
# Text: which is sometimes a a bit tough in in a town like los angeles where i think everybody's on the go trying to accomplish their own goals so they don't, Positive Count: 3, Depressed Count: 0
# Text: it's sometimes hard to find someone who's gonna be uplifting or try to be inspiring so, Positive Count: 2, Depressed Count: 1
# Text: i don't really have anybody in particular but people have kind of brought up things here and there, Positive Count: 0, Depressed Count: 0
# Text: you know just like hey instead of instead of doing this how about doing that or hey you're good at this why aren't you doing that or something like that just you know i'm always looking for new opportunities so they always point out things that maybe i might i could do differently, Positive Count: 2, Depressed Count: 0
# Text: instead of just being negative saying hey don't do that that's no that's why are you doing that it's a waste of time, Positive Count: 0, Depressed Count: 2
# Text: um i guess it depends on who you talk to, Positive Count: 0, Depressed Count: 0
# Text: i'm i'm okay at it i could probably work at that, Positive Count: 1, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: i don't know i mean i can i i think i can do better at it, Positive Count: 1, Depressed Count: 0
# Text: well back to the point about people provoking me so i mean i try not to blow steam and let them get under my skin so i just usually try not to let it get to me, Positive Count: 1, Depressed Count: 1
# Text: but i don't know i guess with temper i guess it depends on how i handle my stress, Positive Count: 0, Depressed Count: 2
# Text: lately i've been better at it just because i think my situation's been a little bit better, Positive Count: 1, Depressed Count: 0
# Text: no, Positive Count: 0, Depressed Count: 0
# Text: no, Positive Count: 0, Depressed Count: 0
# Text: no, Positive Count: 0, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: nothing major, Positive Count: 0, Depressed Count: 0
# Text: i mean maybe when i was younger i could've traveled more or i could've worked towards something that paid better job-wise but i mean, Positive Count: 2, Depressed Count: 0
# Text: those are all things that i think at any point in life you always think like well i coulda shoulda would've done but you know, Positive Count: 2, Depressed Count: 0
# Text: but then again i think that's natural for anybody i mean i could i could've become a banker or i could've become a lawyer or a doctor and made about ten times the money that i make now but, Positive Count: 0, Depressed Count: 0
# Text: but then again i don't like the law and i don't like medicine so so i'm it wasn't meant to be so, Positive Count: 1, Depressed Count: 0
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: so, Positive Count: 0, Depressed Count: 0
# Text: um i think, Positive Count: 0, Depressed Count: 0
# Text: i think my, Positive Count: 0, Depressed Count: 0
# Text: in my life i knew that, Positive Count: 0, Depressed Count: 0
# Text: i there's a lot of things i have <ha> there's more dislikes <laughter> than likes so i kinda narrowed it down to what am i good at and what am i not good at and what am i gonna work well or who who am i gonna work well with and who will i not work well with, Positive Count: 4, Depressed Count: 1
# Text: so i kind of i kinda sorted out and then the list kind of, Positive Count: 0, Depressed Count: 0
# Text: mmm kind of answered itself so, Positive Count: 0, Depressed Count: 0
# Text: no it i don't think it was hard but it was just but i think it was a real reality check and i think it it's kind of a good thing 'cause sometimes trying to conform to doing things that doesn't really fit you doesn't make sense, Positive Count: 1, Depressed Count: 1
# Text: it's like trying to shove a a round peg into a square a square hole and it's like it just no matter how you try to shove it in it's not gonna go in so sometimes it's just might as well go down a path that seems to work better for you, Positive Count: 4, Depressed Count: 0
# Text: memorable experiences um hmm, Positive Count: 1, Depressed Count: 0
# Text: i think it's just i don't really have like any one in particular i think i think every day is almost like a memorable experience whether it's positive or negative i think it's just everything from getting it just just the fact that, Positive Count: 3, Depressed Count: 1
# Text: i got a job and i can i can take care of myself is already almost like a memorable experience maybe for the average person it it sounds stupid but you know i think just the fact that i'm able, Positive Count: 2, Depressed Count: 1
# Text: i'm able to get this far in life without like completely self-destructing is already an accomplishment so i feel like, Positive Count: 2, Depressed Count: 0
# Text: i've gotten somewhere, Positive Count: 0, Depressed Count: 0
# Text: maybe not to not maybe not to the point to the average person they might think like well why aren't you a millionaire but you know what not everybody can be a millionaire, Positive Count: 2, Depressed Count: 0
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: when was the last time i really felt happy, Positive Count: 1, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: i don't know i'm not really someone who's like, Positive Count: 1, Depressed Count: 0
# Text: i don't have any real high highs or low lows i mean i haven't hit any lows so i mean i, Positive Count: 0, Depressed Count: 1
# Text: i don't know i'm usually pretty i feel like i'm a level person and i'm pretty happy <ha> every day i feel like if i accomplish one thing then i'm pretty happy so, Positive Count: 4, Depressed Count: 0
# Text: i guess to answer the question probably, Positive Count: 0, Depressed Count: 0
# Text: mmm probably yesterday i just feel like if i if i'm able to accomplish something then then hey i'm happy, Positive Count: 3, Depressed Count: 0
# Text: i don't know i don't really have a best friend but i mean i well to answer the question generally friends, Positive Count: 2, Depressed Count: 0
# Text: i think they would say that i'm very <ver> pretty outgoing i'm pretty, Positive Count: 1, Depressed Count: 0
# Text: determined, Positive Count: 0, Depressed Count: 0
# Text: i'm trying you know i try to you know i try to interact as much as possible i'm always out networking as much as possible, Positive Count: 0, Depressed Count: 0
# Text: so, Positive Count: 0, Depressed Count: 0
# Text: i don't know i guess that's basically what i think they would describe me as, Positive Count: 0, Depressed Count: 0
# Text: okay, Positive Count: 0, Depressed Count: 0
# Text: no problem, Positive Count: 0, Depressed Count: 1
# Text: alright, Positive Count: 0, Depressed Count: 0
# Text: bye, Positive Count: 0, Depressed Count: 0
# Text: i'm fine how about yourself , Positive Count: 1, Depressed Count: 0
# Text: i'm from los angeles california, Positive Count: 0, Depressed Count: 0
# Text: what part , Positive Count: 0, Depressed Count: 0
# Text: okay , Positive Count: 0, Depressed Count: 0
# Text: um all my family's here friends, Positive Count: 0, Depressed Count: 0
# Text: a mixture of people and a lot of things to do, Positive Count: 0, Depressed Count: 0
# Text: early childhood education, Positive Count: 0, Depressed Count: 0
# Text: no not right now but i would love to get back into it, Positive Count: 2, Depressed Count: 0
# Text: love working with kids seeing them smile, Positive Count: 2, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: guess it goes back to when i was a kid uh i like being happy and playful so i guess it just transferred into my adult life, Positive Count: 3, Depressed Count: 0
# Text: working with kids as a school teacher or in that capacity, Positive Count: 0, Depressed Count: 0
# Text: yeah it is but if it's a passion of yours it'll always be fun, Positive Count: 2, Depressed Count: 0
# Text: i'm very close, Positive Count: 0, Depressed Count: 0
# Text: sometimes too close, Positive Count: 0, Depressed Count: 0
# Text: um i have four sisters and one brother on my mom's side and on my dad i have, Positive Count: 0, Depressed Count: 0
# Text: six brothers and four sisters and we're all getting intertwined together so so that's why i say we're too close sometimes, Positive Count: 0, Depressed Count: 0
# Text: no, Positive Count: 0, Depressed Count: 0
# Text: i have a lot of friends to interact with and uh we're always doing different things so that's why i say i'm not, Positive Count: 0, Depressed Count: 0
# Text: curse, Positive Count: 0, Depressed Count: 1
# Text: <laughter>, Positive Count: 0, Depressed Count: 0
# Text: just let it out, Positive Count: 0, Depressed Count: 0
# Text: a couple days ago my nephew, Positive Count: 0, Depressed Count: 0
# Text: didn't call me back, Positive Count: 0, Depressed Count: 0
# Text: um kinda mad 'cause i had set aside some time to spend with him and he just blew it off and didn't call me back, Positive Count: 0, Depressed Count: 1
# Text: yeah i know, Positive Count: 0, Depressed Count: 0
# Text: mm i'm okay, Positive Count: 0, Depressed Count: 0
# Text: when my mother passed, Positive Count: 0, Depressed Count: 0
# Text: uh it's been about, Positive Count: 0, Depressed Count: 0
# Text: five years now to the day, Positive Count: 0, Depressed Count: 0
# Text: so, Positive Count: 0, Depressed Count: 0
# Text: it's it's getting better, Positive Count: 1, Depressed Count: 0
# Text: time makes it easier, Positive Count: 1, Depressed Count: 0
# Text: a lot, Positive Count: 0, Depressed Count: 0
# Text: 'cause there's a lot of things that make me think about her in a daily basis, Positive Count: 0, Depressed Count: 0
# Text: anything uh driving by a particular, Positive Count: 0, Depressed Count: 0
# Text: restaurant that she likes uh watching different t_v shows, Positive Count: 1, Depressed Count: 0
# Text: just anything that could trigger a a memory, Positive Count: 0, Depressed Count: 0
# Text: of my mom, Positive Count: 0, Depressed Count: 0
# Text: yesterday, Positive Count: 0, Depressed Count: 0
# Text: uh think about the good times and, Positive Count: 1, Depressed Count: 0
# Text: i don't stay in that place too long just, Positive Count: 0, Depressed Count: 0
# Text: go ahead and think about it and move on, Positive Count: 0, Depressed Count: 0
# Text: mm not officially but i think i might be depressed, Positive Count: 0, Depressed Count: 1
# Text: well, Positive Count: 1, Depressed Count: 0
# Text: i mean since my mom passed it's been kinda rough, Positive Count: 0, Depressed Count: 1
# Text: and then um, Positive Count: 0, Depressed Count: 0
# Text: job situation is not stable here in california so that has a lot to do with it as well so, Positive Count: 2, Depressed Count: 0
# Text: yeah it is but, Positive Count: 0, Depressed Count: 0
# Text: kinda sort of kinda just to myself, Positive Count: 0, Depressed Count: 0
# Text: reserved , Positive Count: 0, Depressed Count: 0
# Text: mm not really, Positive Count: 0, Depressed Count: 0
# Text: it's pretty easy, Positive Count: 2, Depressed Count: 0
# Text: grumpy irritable, Positive Count: 0, Depressed Count: 2
# Text: fidgety, Positive Count: 0, Depressed Count: 1
# Text: just a big ball of nerves , Positive Count: 0, Depressed Count: 0
# Text: uh what do you mean, Positive Count: 0, Depressed Count: 0
# Text: uh i guess so yeah i like to travel, Positive Count: 1, Depressed Count: 0
# Text: meeting new people, Positive Count: 0, Depressed Count: 0
# Text: different locations scenery, Positive Count: 0, Depressed Count: 0
# Text: uh different opportunities to try something new in a new location, Positive Count: 0, Depressed Count: 0
# Text: uh just came back from memphis about three weeks ago, Positive Count: 0, Depressed Count: 0
# Text: go and see family and friends uh it was pretty nice got a chance to, Positive Count: 2, Depressed Count: 0
# Text: see um, Positive Count: 0, Depressed Count: 0
# Text: something new, Positive Count: 0, Depressed Count: 0
# Text: change <cha> change of scenery, Positive Count: 0, Depressed Count: 0
# Text: wow, Positive Count: 1, Depressed Count: 0
# Text: stick to the plan and don't, Positive Count: 0, Depressed Count: 0
# Text: veer off to the left or right just go straight ahead, Positive Count: 1, Depressed Count: 0
# Text: um , Positive Count: 0, Depressed Count: 0
# Text: just different circumstances in life that, Positive Count: 0, Depressed Count: 0
# Text: gradually pushed me towards the left and the right, Positive Count: 1, Depressed Count: 0
# Text: every day, Positive Count: 0, Depressed Count: 0
# Text: uh a few relationships not staying in school, Positive Count: 0, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: missing out on great opportunities with employers, Positive Count: 1, Depressed Count: 0
# Text: um funny, Positive Count: 0, Depressed Count: 1
# Text: loyal, Positive Count: 1, Depressed Count: 0
# Text: spontaneous, Positive Count: 1, Depressed Count: 0
# Text: life of the party, Positive Count: 0, Depressed Count: 0
# Text: grew up together in the same community, Positive Count: 0, Depressed Count: 0
# Text: went to school together high school friends, Positive Count: 0, Depressed Count: 0
# Text: uh my big sister michelle, Positive Count: 0, Depressed Count: 0
# Text: uh my friend troy, Positive Count: 0, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: i mean there's others but those two uh no matter good or bad they're always, Positive Count: 1, Depressed Count: 1
# Text: in my corner for me, Positive Count: 0, Depressed Count: 0
# Text: thank you, Positive Count: 1, Depressed Count: 0
# Text: yesterday <yester> yesterday celebrated a birthday, Positive Count: 1, Depressed Count: 0
# Text: oh it was just a little small intimate, Positive Count: 1, Depressed Count: 0
# Text: setting , Positive Count: 0, Depressed Count: 0
# Text: cooked a a meal had family and friends over, Positive Count: 0, Depressed Count: 0
# Text: listened to music watched movie talked, Positive Count: 0, Depressed Count: 0
# Text: about the old days when my mom was here and when we were all one union, Positive Count: 0, Depressed Count: 0
# Text: so it was just a nice evening, Positive Count: 1, Depressed Count: 0
# Text: thank you, Positive Count: 1, Depressed Count: 0
# Text: bye bye, Positive Count: 0, Depressed Count: 0
# Text: okay how 'bout yourself, Positive Count: 0, Depressed Count: 0
# Text: here in california, Positive Count: 0, Depressed Count: 0
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: oh well that it's big and broad there's a lot to do a lot of um, Positive Count: 1, Depressed Count: 0
# Text: um job opportunities than other states, Positive Count: 0, Depressed Count: 0
# Text: um pretty much that it's big and there's a lot you can do here, Positive Count: 1, Depressed Count: 0
# Text: traffic um maybe the violence rate bad news even though you know you wanna know what's going on in your environment but you still have to watch it so you can you know look out to see what's going on on a daily basis, Positive Count: 0, Depressed Count: 1
# Text: sociology i have a um two year degree in liberal arts but my major was sociology, Positive Count: 0, Depressed Count: 0
# Text: no i'm actually an m_t_a bus operator, Positive Count: 0, Depressed Count: 0
# Text: well since metro is steady growing um my dream job is to move up in the company and i'm about to actually start some classes for supervisory next week so um 'cause they look to promote within the company so that's the good thing there's a lot of opportunities at metro where you can take classes and they'll pay for your tuition and things of that nature, Positive Count: 3, Depressed Count: 0
# Text: thanks, Positive Count: 0, Depressed Count: 0
# Text: well it's not actually hard as right now it's easy if you take advantage of it right now 'cause they look to promote within so you know so since i'm already working there that's a good thing so it's good to go ahead and take the classes that you need that you're interested in and go ahead and move up the ladder as soon as possible , Positive Count: 5, Depressed Count: 1
# Text: what do you mean i'm sorry, Positive Count: 0, Depressed Count: 1
# Text: okay, Positive Count: 0, Depressed Count: 0
# Text: read take a long walk hot bath meditate just close my eyes sometimes, Positive Count: 1, Depressed Count: 0
# Text: i'm pretty much good because see by me being a bus operator you run into circumstances and situations you gotta remain calm and still remain professional at the same time, Positive Count: 3, Depressed Count: 0
# Text: well i look at it like it it goes with i mean it comes with experience you know um you do something on a continuous basis usually you some somewhere down the line you become good at it you know so i i look at it like that so i've been driving for years and dealing with the public so it's just how you handle circumstances you you know treat people like you wanna be treated, Positive Count: 3, Depressed Count: 0
# Text: no i'm pretty good at it now, Positive Count: 2, Depressed Count: 0
# Text: maybe when i was younger you know you as you get older you get wiser you learn different things and i'm still learning today, Positive Count: 0, Depressed Count: 0
# Text: i would say my family you know my kids you know even though you know i had been having a lot of deaths around me but that's just go that's part of the life experience you know you born here but you gotta leave here one day but, Positive Count: 0, Depressed Count: 0
# Text: my kids will keep me you know sane and you know i love them and my family  , Positive Count: 2, Depressed Count: 0
# Text: thank you, Positive Count: 1, Depressed Count: 0
# Text: no <laughter>, Positive Count: 0, Depressed Count: 0
# Text: um setting good examples you know because you're the first teacher you know and you wanna set a positive good example for your kids and i think that's a good thing and it starts at home, Positive Count: 2, Depressed Count: 0
# Text: well um, Positive Count: 1, Depressed Count: 0
# Text: by you being the first teacher your kids you're you're their one that they see on a daily basis when they wake up so whatever's been taught in the home they lookin' and learning every day you know whether it's a home school you know people kids have a tendency to do things what they see you know what i mean  so you try to keep it positive teach 'em good morals and values and how to get along with other people regardless of race and you know different things of that nature, Positive Count: 2, Depressed Count: 0
# Text: i have a um four and a half year old son i have a seven year old daughter and i also have a twenty three year old, Positive Count: 0, Depressed Count: 0
# Text: yeah i'm 'bout to be, Positive Count: 0, Depressed Count: 0
# Text: well my daughter's pregnant with a boy she has three um little girls so i have three grandkids and um one on the way which is a boy this time, Positive Count: 1, Depressed Count: 0
# Text: yeah thank you, Positive Count: 1, Depressed Count: 0
# Text: the hardest thing is, Positive Count: 0, Depressed Count: 0
# Text: well right now i'm a single parent so that makes it hard alone itself you know and, Positive Count: 2, Depressed Count: 2
# Text: they can be expensive at times you know it depends on the person's situation you know the whether they have help or a job you know things of that nature to help the situation better but it's hard you know but you i try to you know keep a job keep food in the house you know just maintain and support my kids the best way i can, Positive Count: 3, Depressed Count: 2
# Text: with my kids or just period, Positive Count: 0, Depressed Count: 0
# Text: what's memorable for me is that i'm the only one in my family with a degree so it's kinda like yeah it's kinda even though i'm the baby of ten kids you know, Positive Count: 2, Depressed Count: 0
# Text: and i've always kept that in the back of my mind even though everybody well pretty much my whole family have decent job but i'm the only one with a degree so i kinda like gave myself a pat on the back like you know, Positive Count: 4, Depressed Count: 0
# Text: you know i just that's the only thing i remember graduating you know and my family there and to support me , Positive Count: 1, Depressed Count: 0
# Text: thank you, Positive Count: 1, Depressed Count: 0
# Text: happy that i accomplished something you know just even though it may not be much but it was better than just have having a high school diploma and i had um i was working on my bachelor's degree but i ended up in a bad car accident i never went back i got distracted and you know i was working at the same time but i was just like moreso i needed income than than um schooling at that time because i was a young parent you know 'cause i had my daughter at seventeen so i was like i needed the money to support her but i never went back but i feel like it's never too late so, Positive Count: 5, Depressed Count: 2
# Text: i feel like i'll take some classes now that i'm with metro to help me move up the ladder so  that's why i'm starting a class next week, Positive Count: 1, Depressed Count: 0
# Text: thank you, Positive Count: 1, Depressed Count: 0
# Text: hm, Positive Count: 0, Depressed Count: 0
# Text: well the advice i would've gave myself, Positive Count: 1, Depressed Count: 0
# Text: that i probably wouldn't have been a young mother at a young age and that, Positive Count: 0, Depressed Count: 0
# Text: i probably would've, Positive Count: 0, Depressed Count: 0
# Text: stayed in school you know not let the accident just distract me and not i would've remained in school i probably wouldn't have had kids early you know um, Positive Count: 0, Depressed Count: 1
# Text: rather i probably would've stayed in school and probably have a part time job or something just i just feel like um, Positive Count: 1, Depressed Count: 0
# Text: education is a excellent thing for a person just having knowledge and learning different things keeping your mind open to learning new ideas every day, Positive Count: 1, Depressed Count: 0
# Text: so i think that's a plus you know in anybody's shoes just to better they selves you know through education maybe to um maybe promote within your company or whatever the case may be that they help better your career, Positive Count: 1, Depressed Count: 0
# Text: i'm not quite sure um, Positive Count: 0, Depressed Count: 0
# Text: you learn from your mistakes you know but at the same time you don't continue to make the same ones i feel like it's okay to make a mistake but long as you do something to change you know um like myself even though i'm going to school late but still i'm going you know i wanna better myself career wise so , Positive Count: 3, Depressed Count: 2
# Text: yes, Positive Count: 0, Depressed Count: 0
# Text: my oldest daughter, Positive Count: 0, Depressed Count: 0
# Text: we had a argument because, Positive Count: 0, Depressed Count: 0
# Text: just, Positive Count: 0, Depressed Count: 0
# Text: the life that she's living right now and the things that she's going through, Positive Count: 1, Depressed Count: 0
# Text: and um i had told her that she just needed to make some changes to better her situation, Positive Count: 1, Depressed Count: 0
# Text: and uh we got into an argument because you know how your kids sometimes don't wanna hear it you know, Positive Count: 0, Depressed Count: 0
# Text: hear the stuff that you're saying even though it's true or , Positive Count: 0, Depressed Count: 0
# Text: or they just you know well they just don't wanna hear it you know they may be going through something they don't wanna hear but we got into a argument about it but, Positive Count: 1, Depressed Count: 0
# Text: that just happened you know, Positive Count: 0, Depressed Count: 0
# Text: i just told her i'm not, Positive Count: 0, Depressed Count: 0
# Text: i'm sorry, Positive Count: 0, Depressed Count: 1
# Text: very close, Positive Count: 0, Depressed Count: 0
# Text: very close it's just that the the situation my daughter's in she just needs to make some changes to better her her life, Positive Count: 1, Depressed Count: 0
# Text: and I'll be telling, Positive Count: 0, Depressed Count: 0
# Text: she's um, Positive Count: 0, Depressed Count: 0
# Text: she's kinda like stubborn in her own way you know i was raised to listen to your mom you know your mom's not gonna tell you nothing wrong and i've been telling her over the years you know different things and it's it's kinda like i was talking to a wall because she she did the opposite, Positive Count: 1, Depressed Count: 2
# Text: and now she's she regretting it you know 'cause she's like my mom told me this you know mom i'm doing the opposite so i guess she gotta bump her head a couple of times to get it it's kinda like i done told you i done left it alone and now it's up to you to make the change, Positive Count: 1, Depressed Count: 2
# Text: it's very frustrating because it's like i'm talking to a wall and she's not hearing me and i'm like it seem like it's taking forever for her to change but it's left up to the individual whenever they're ready you know what i mean once the person get tired of something they'll make it change it may not be when you want it to happen but, Positive Count: 2, Depressed Count: 2
# Text: the ball is her court you know, Positive Count: 0, Depressed Count: 0
# Text: i only can do so much, Positive Count: 0, Depressed Count: 0
# Text: oh wow, Positive Count: 1, Depressed Count: 0
# Text: i have my days um, Positive Count: 0, Depressed Count: 0
# Text: since i have two little ones um i kinda like trained them to go to bed at eight o clock because you know they gotta go to school and i think it's important to have a good night's rest because it kinda like, Positive Count: 3, Depressed Count: 0
# Text: <clears throat> it it kinda like gets you ready for the next day or you know how you gonna feel if you rested what type of person you'll be that day you know 'cause everybody have they days whether they're good or bad but that's just a part of life and i feel like if you had a good night's good good night's rest hopefully you'll have a good day you know, Positive Count: 3, Depressed Count: 1
# Text: pretty much you know i need my rest because i'm out there driving that bus and dealing with all these people and you know  the job itself if very stressful so i feel like if i'm rested it'll help me, Positive Count: 2, Depressed Count: 1
# Text: what am i like irritated tired um lazy, Positive Count: 1, Depressed Count: 3
# Text: you know, Positive Count: 0, Depressed Count: 0
# Text: feel like i wanna lay down probably go to sleep <laughter> get the rest that i need but <laughter>, Positive Count: 1, Depressed Count: 0
# Text: i never thought about that, Positive Count: 0, Depressed Count: 0
# Text: i just you know, Positive Count: 0, Depressed Count: 0
# Text: 'cause like i said you know everybody have their moments they do i never thought about that, Positive Count: 1, Depressed Count: 0
# Text: hm, Positive Count: 0, Depressed Count: 0
# Text: no, Positive Count: 0, Depressed Count: 0
# Text: no, Positive Count: 0, Depressed Count: 0
# Text: i don't really have a best friend but a person that i deal with and i used to work with um she would probably tell you that i'm very um outgoing a go getter, Positive Count: 2, Depressed Count: 0
# Text: dependable responsible, Positive Count: 1, Depressed Count: 0
# Text: i'm a um people person, Positive Count: 0, Depressed Count: 0
# Text: i get along with others you know i'm kinda like, Positive Count: 1, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: i leave a good a a good mark, Positive Count: 1, Depressed Count: 0
# Text: whether i know you or not if you was to you know like , Positive Count: 1, Depressed Count: 0
# Text: like you and i now you know i um, Positive Count: 1, Depressed Count: 0
# Text: you'd probably say oh she seems like a nice young lady or whatever you know something like that, Positive Count: 2, Depressed Count: 0
# Text: thank you, Positive Count: 1, Depressed Count: 0
# Text: well, Positive Count: 1, Depressed Count: 0
# Text: i try to stay happy i'd rather be happy than sad my kids keep me going you know what i mean, Positive Count: 1, Depressed Count: 1
# Text: especially when i go to pick them up from school or their being hey mom you know that just kinda make my day, Positive Count: 0, Depressed Count: 0
# Text: just them run up to me you know and be happy and excited you know what i mean , Positive Count: 2, Depressed Count: 0
# Text: thank you, Positive Count: 1, Depressed Count: 0
# Text: you're more than welcome you have a good day, Positive Count: 2, Depressed Count: 0
# Text: goodbye, Positive Count: 0, Depressed Count: 0
# Text: i'm doing good um, Positive Count: 1, Depressed Count: 0
# Text: from los angeles california, Positive Count: 0, Depressed Count: 0
# Text: um the cool weather the beaches the people the schools , Positive Count: 1, Depressed Count: 0
# Text: um child development, Positive Count: 0, Depressed Count: 0
# Text: yes, Positive Count: 0, Depressed Count: 0
# Text: to be a teacher for special education, Positive Count: 0, Depressed Count: 0
# Text: it's not hard 'cause i love to work with children, Positive Count: 2, Depressed Count: 1
# Text: yes, Positive Count: 0, Depressed Count: 0
# Text: dishonesty maybe, Positive Count: 0, Depressed Count: 1
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: like if a guy like especially when it comes to relationships when they lie to you about something that's very minimal, Positive Count: 1, Depressed Count: 1
# Text: my mom i wanna say my mom, Positive Count: 0, Depressed Count: 0
# Text: um very close we talk every day, Positive Count: 0, Depressed Count: 0
# Text: very close even though i don't live with them i try to see them as much as i can, Positive Count: 0, Depressed Count: 0
# Text: uh it's okay <laughter>, Positive Count: 0, Depressed Count: 0
# Text: it's it's good, Positive Count: 1, Depressed Count: 0
# Text: it's, Positive Count: 0, Depressed Count: 0
# Text: yes i do , Positive Count: 0, Depressed Count: 0
# Text: um they're they're friendly it's just that they're very quiet, Positive Count: 2, Depressed Count: 0
# Text: 'cause i'm not used to that environment, Positive Count: 0, Depressed Count: 0
# Text: it's fine like the how much it costs is very cheap so that's good and they're friendly so it's fine I just wish it was a little bit it could've been better so yeah , Positive Count: 5, Depressed Count: 1
# Text: yes <laughter> , Positive Count: 0, Depressed Count: 0
# Text: um i had a different option to live with somebody else, Positive Count: 0, Depressed Count: 0
# Text: and i'm still friends with the female and comes to find out that we connect more than the roommates that I live with so I kinda regret moving in with the roommates I have now versus who i was supposed to move with in the beginning so but i'm stuck for a year so it's whatever , Positive Count: 0, Depressed Count: 2
# Text: that's fine, Positive Count: 1, Depressed Count: 0
# Text: how do i know who, Positive Count: 0, Depressed Count: 0
# Text: i, Positive Count: 0, Depressed Count: 0
# Text: yeah <laughter>, Positive Count: 0, Depressed Count: 0
# Text: there's nothing that really gets me really mad that i can think of the top of my head, Positive Count: 1, Depressed Count: 1
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: maybe when it comes to schools how they treat the children especially children of color maybe , Positive Count: 0, Depressed Count: 0
# Text: that really gets me mad, Positive Count: 0, Depressed Count: 1
# Text: mm yes , Positive Count: 0, Depressed Count: 0
# Text: because i do things from within i guess so um internally motivated to do things i guess yeah, Positive Count: 1, Depressed Count: 0
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: wow, Positive Count: 1, Depressed Count: 0
# Text: i hardly ever argue with somebody <laughter>, Positive Count: 0, Depressed Count: 0
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: oh my sister i guess my sister that was about a month ago, Positive Count: 0, Depressed Count: 0
# Text: uh i felt very betrayed and belittled because she's my little sister and she shouldn't be disrespecting me in any type of way because i'm an adult so yeah i was not feeling the situation at all, Positive Count: 0, Depressed Count: 2
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: just her getting into grown folks' business and, Positive Count: 0, Depressed Count: 0
# Text: it was a conversation between me and my mother and i guess she overheard what was being said, Positive Count: 0, Depressed Count: 0
# Text: and she felt like through my actions that i was choosing somebody else over my family when that wasn't even the case but because she didn't know the whole situation she just automatically assumed and put stuff on facebook about me disrespecting me calling me out by name and it was just yeah so <laughter> , Positive Count: 1, Depressed Count: 1
# Text: and she then comes to me about it like she did all this other stuff on facebook i don't that's one thing i don't like either is when you i hate indirect comments like if you have if you need to talk to me come directly to me don't put it on facebook tell other people, Positive Count: 1, Depressed Count: 1
# Text: that's a pet peeve of mine so i really don't like that, Positive Count: 1, Depressed Count: 1
# Text: yeah so but i mean we're fine now, Positive Count: 1, Depressed Count: 0
# Text: so that's good, Positive Count: 1, Depressed Count: 0
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: to not , Positive Count: 0, Depressed Count: 0
# Text: believe people so easily, Positive Count: 0, Depressed Count: 0
# Text: so gullible to not be so gullible, Positive Count: 0, Depressed Count: 1
# Text: i guess i've been hearing that lately how i believe anybody anything that somebody says without really thinking about it or without having them prove it so i guess you could say i let i made a lot of mistakes i don't wanna say i regretted it because i'm glad i went through it while i was younger than me getting older and going through the same situations so um, Positive Count: 1, Depressed Count: 2
# Text: yeah i believe people too easily and i give people too much chances , Positive Count: 0, Depressed Count: 0
# Text: so, Positive Count: 0, Depressed Count: 0
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: when i went on a cruise which was a happy experience when i went on a cruise to mexico with my family um  when i was sixteen about six years ago, Positive Count: 1, Depressed Count: 0
# Text: yeah <laughter>, Positive Count: 0, Depressed Count: 0
# Text: yeah i mean yeah i guess it was <laughter>, Positive Count: 0, Depressed Count: 0
# Text: no i really want to though, Positive Count: 0, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: trying new things seeing new views of the world um trying the different type of foods um seeing how the government is and how they run the things out there i guess, Positive Count: 0, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: yeah i plan to go to the bahamas next year, Positive Count: 0, Depressed Count: 0
# Text: i plan to do a lot of traveling next year actually, Positive Count: 0, Depressed Count: 0
# Text: so, Positive Count: 0, Depressed Count: 0
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: it's pretty good, Positive Count: 2, Depressed Count: 0
# Text: eh somewhat, Positive Count: 0, Depressed Count: 0
# Text: i'm tired <laughter> and i kind of fall asleep during class and whatnot, Positive Count: 0, Depressed Count: 2
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: it's my fault though, Positive Count: 0, Depressed Count: 1
# Text: um probably today, Positive Count: 0, Depressed Count: 0
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: well i fell asleep late so <laughter> it's my fault, Positive Count: 1, Depressed Count: 2
# Text: um no i feel pretty happy right now, Positive Count: 3, Depressed Count: 0
# Text: mhm, Positive Count: 0, Depressed Count: 0
# Text: no, Positive Count: 0, Depressed Count: 0
# Text: no, Positive Count: 0, Depressed Count: 0
# Text: no, Positive Count: 0, Depressed Count: 0
# Text: very friendly and funny, Positive Count: 1, Depressed Count: 1
# Text: talkative, Positive Count: 0, Depressed Count: 0
# Text: um through high school , Positive Count: 0, Depressed Count: 0
# Text: we're pretty close we try to talk as often as possible maybe once a week i'll try to see them at least every few months, Positive Count: 1, Depressed Count: 0
# Text: mm they're everywhere <laughter> um yeah, Positive Count: 0, Depressed Count: 0
# Text: no comment on that, Positive Count: 0, Depressed Count: 0
# Text: they're more smarter they are learning more stuff than we learned back in the day they are learning they're very progressing but when it comes to technology they're not outside they're always on the computer on their phones they don't play outside no more they don't care about nature or the little things in life they just yeah but when it comes to their mentality they argue smarter 'cause the schools are getting better i ain't gonna lie so , Positive Count: 2, Depressed Count: 1
# Text: when what happened, Positive Count: 0, Depressed Count: 0
# Text: i was just, Positive Count: 0, Depressed Count: 0
# Text: okay, Positive Count: 0, Depressed Count: 0
# Text: um last weekend i guess, Positive Count: 0, Depressed Count: 0
# Text: right now, Positive Count: 1, Depressed Count: 0
# Text: um , Positive Count: 0, Depressed Count: 0
# Text: what did i do, Positive Count: 0, Depressed Count: 0
# Text: um being with my boyfriend makes me really happy so i was just hanging out with him last weekend and i never really get to see him that much so yeah  , Positive Count: 1, Depressed Count: 0
# Text: 'cause he works i have school different schedules, Positive Count: 1, Depressed Count: 0
# Text: it's not that bad <laughter>, Positive Count: 0, Depressed Count: 1
# Text: um he's my boyfriend i've been knowing for what about six months now , Positive Count: 0, Depressed Count: 0
# Text: we met through a mutual friend um , Positive Count: 0, Depressed Count: 0
# Text: in l_a i guess, Positive Count: 0, Depressed Count: 0
# Text: okay, Positive Count: 0, Depressed Count: 0
# Text: you're welcome, Positive Count: 1, Depressed Count: 0
# Text: bye, Positive Count: 0, Depressed Count: 0
# Text: i'm doing alright, Positive Count: 0, Depressed Count: 0
# Text: uh originally i'm from california, Positive Count: 0, Depressed Count: 0
# Text: uh born in glendale, Positive Count: 0, Depressed Count: 0
# Text: i'm not too happy with it, Positive Count: 1, Depressed Count: 0
# Text: uh just unemployed at the moment but uh, Positive Count: 0, Depressed Count: 1
# Text: actively seeking uh, Positive Count: 0, Depressed Count: 0
# Text: uh doing what i'm supposed to be doing uh there are some uh , Positive Count: 0, Depressed Count: 0
# Text: some prospects there but hopefully i'll learn something today, Positive Count: 0, Depressed Count: 0
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: well i have one it's a girlfriend so i consider her a roommate a lover type thing, Positive Count: 2, Depressed Count: 0
# Text: pardon me, Positive Count: 1, Depressed Count: 0
# Text: um we're pretty close, Positive Count: 1, Depressed Count: 0
# Text: uh i met her last year and uh, Positive Count: 0, Depressed Count: 0
# Text: we've been through some, Positive Count: 0, Depressed Count: 0
# Text: troubling times but uh we're starting to see a light at the end of the tunnel, Positive Count: 0, Depressed Count: 1
# Text: uh, Positive Count: 0, Depressed Count: 0
# Text: the troubling times, Positive Count: 0, Depressed Count: 1
# Text: uh, Positive Count: 0, Depressed Count: 0
# Text: i would, Positive Count: 0, Depressed Count: 0
# Text: let me see uh, Positive Count: 0, Depressed Count: 0
# Text: well, Positive Count: 1, Depressed Count: 0
# Text: i had uh gotten a d_u_i last year and uh lost my job i'm a truck driver by trade so , Positive Count: 0, Depressed Count: 1
# Text: uh that kinda, Positive Count: 0, Depressed Count: 0
# Text: threw me way off uh having a fourteen hundred dollar a week job uh and then going to nothing kinda like plus losing my my license kinda really threw me off, Positive Count: 1, Depressed Count: 1
# Text: and uh I couldn't um, Positive Count: 0, Depressed Count: 0
# Text: i haven't really uh, Positive Count: 0, Depressed Count: 0
# Text: found anything that i was interested in uh so i started cooking, Positive Count: 0, Depressed Count: 0
# Text: and our trying to see which other route i can go as far as uh having some kind of a career and uh, Positive Count: 0, Depressed Count: 0
# Text: so, Positive Count: 0, Depressed Count: 0
# Text: i'm choose choosing to go into the culinary field but you know uh meanwhile i still have to work it's hard to find work with uh without going to school , Positive Count: 1, Depressed Count: 1
# Text: and uh so, Positive Count: 0, Depressed Count: 0
# Text: but i think today uh i applied at ralphs so hopefully i'll get that job i should have that job actually so, Positive Count: 0, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: but i'm starting to see a light like i said at the end of the tunnel now a little by little, Positive Count: 1, Depressed Count: 0
# Text: my dream job would be probably forestry service, Positive Count: 0, Depressed Count: 0
# Text: out in the wilderness yeah, Positive Count: 0, Depressed Count: 0
# Text: i like being alone, Positive Count: 1, Depressed Count: 1
# Text: pardon me, Positive Count: 1, Depressed Count: 0
# Text: well, Positive Count: 1, Depressed Count: 0
# Text: you know i have a a lot of for animals i'm an exotic animal trainer by trade and uh so and i like  being i don't like people too much, Positive Count: 1, Depressed Count: 0
# Text: uh so being outdoors and uh i've always enjoyed being outdoors that's how i like being a truck driver i've traveled the world, Positive Count: 2, Depressed Count: 0
# Text: i don't necessarily like being in a warehouse or an office i'm of a a, Positive Count: 1, Depressed Count: 0
# Text: outdoors type of guy so, Positive Count: 0, Depressed Count: 0
# Text: uh one of my trips would be uh, Positive Count: 0, Depressed Count: 0
# Text: i spent a year and a half in japan and uh on the uh lower island uh there that uh they built that bridge , Positive Count: 0, Depressed Count: 0
# Text: uh the largest bridge in the world uh and uh, Positive Count: 0, Depressed Count: 0
# Text: i went there to work for , Positive Count: 1, Depressed Count: 0
# Text: uh for an all white oh uh an all white tiger act and uh working for a japanese circus , Positive Count: 0, Depressed Count: 0
# ...
# Text: very mean and he didn't seem i mean he yelled at me but it didn't seem, Positive Count: 0, Depressed Count: 0
# Text: like he gave it much thought it seemed like it was just sort of a stock, Positive Count: 1, Depressed Count: 0
# Text: speech he gave everyone that he thought needed some yelling at so i understand 'cause that's his job, Positive Count: 0, Depressed Count: 0
# Text: but it was, Positive Count: 0, Depressed Count: 0
# Text: was not, Positive Count: 0, Depressed Count: 0
# Text: great for me 'cause i wasn't i i was really anxious in that situation, Positive Count: 1, Depressed Count: 1
# Text: well i would've been twelve, Positive Count: 1, Depressed Count: 0
# Text: and two, Positive Count: 0, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: but i think, Positive Count: 0, Depressed Count: 0
# Text: i think i would've told myself at twelve not to be so hard on myself and not to be so hard on my parents 'cause i think, Positive Count: 0, Depressed Count: 1
# Text: i was a little selfish and self-involved back then, Positive Count: 0, Depressed Count: 1
# Text: i can't really think of anything i mean i regret how i treated my mother when i was a kid but everyone does that and, Positive Count: 0, Depressed Count: 1
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: i do regret, Positive Count: 0, Depressed Count: 1
# Text: a couple of, Positive Count: 0, Depressed Count: 0
# Text: semesters ago i didn't do so well in school and i got a, Positive Count: 1, Depressed Count: 0
# Text: a few ws which i now have to work to get off on my transcript, Positive Count: 1, Depressed Count: 0
# Text: i think so i'm, Positive Count: 0, Depressed Count: 0
# Text: i think i, Positive Count: 0, Depressed Count: 0
# Text: i wasn't focusing in school at that time, Positive Count: 0, Depressed Count: 0
# Text: and i didn't see any counselors at school or anything so i definitely could've done that, Positive Count: 0, Depressed Count: 0
# Text: hmm i think i'd probably spend my ideal weekend sleeping in saturday and then, Positive Count: 1, Depressed Count: 0
# Text: going hiking or maybe just going to the duck pond by my house and feeding ducks and picking some oranges, Positive Count: 0, Depressed Count: 0
# Text: and then maybe, Positive Count: 0, Depressed Count: 0
# Text: going out to breakfast sunday and just like window shopping, Positive Count: 1, Depressed Count: 0
# Text: and maybe watching a little bit of t_v, Positive Count: 0, Depressed Count: 0
# Text: huh, Positive Count: 0, Depressed Count: 0
# Text: well my youngest brother is autistic and my mom and dad were always working when he was growing up, Positive Count: 1, Depressed Count: 0
# Text: i'm ten years older than him so, Positive Count: 0, Depressed Count: 0
# Text: and being the oldest i always i always took care of him which, Positive Count: 0, Depressed Count: 0
# Text: made me really really patient because he was a handful but i'm really proud of how he turned out and, Positive Count: 2, Depressed Count: 0
# Text: um and how close we are, Positive Count: 0, Depressed Count: 0
# Text: <synch>, Positive Count: 0, Depressed Count: 0
# Text: yes, Positive Count: 0, Depressed Count: 0
# Text: huh overwhelmed, Positive Count: 0, Depressed Count: 1
# Text: i have a funeral to attend tomorrow i found out from my doctor i got some, Positive Count: 0, Depressed Count: 0
# Text: health issues, Positive Count: 0, Depressed Count: 1
# Text: it is hard, Positive Count: 0, Depressed Count: 1
# Text: honey i am just putting one foot in front of the other and just trying to get it done, Positive Count: 0, Depressed Count: 0
# Text: like i said i'm overwhelmed but i can't stop doing what i need to do, Positive Count: 1, Depressed Count: 1
# Text: i am from united states of america i was born here in los angeles, Positive Count: 0, Depressed Count: 0
# Text: oh i love the beach honey i like the weather, Positive Count: 2, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: the beach and the weather, Positive Count: 0, Depressed Count: 0
# Text: oh the traffic, Positive Count: 0, Depressed Count: 0
# Text: and the people, Positive Count: 0, Depressed Count: 0
# Text: and this hollywood type image, Positive Count: 0, Depressed Count: 0
# Text: uh not as much as i used to but i've been to europe i went on a, Positive Count: 0, Depressed Count: 0
# Text: uh on a cruise um several cruise, Positive Count: 0, Depressed Count: 0
# Text: uh been to jamaica canada mexico, Positive Count: 0, Depressed Count: 0
# Text: spain morocco um, Positive Count: 0, Depressed Count: 0
# Text: london, Positive Count: 0, Depressed Count: 0
# Text: portugal <por> portugal yeah, Positive Count: 0, Depressed Count: 0
# Text: and i'm going to hawaii in august, Positive Count: 0, Depressed Count: 0
# Text: meeting new people and just seeing new things and just, Positive Count: 0, Depressed Count: 0
# Text: assimilating into other people's culture and, Positive Count: 0, Depressed Count: 0
# Text: uh customs and traditions, Positive Count: 0, Depressed Count: 0
# Text: oh the best trip i ever took is when i, Positive Count: 1, Depressed Count: 0
# Text: was a student at santa monica college and, Positive Count: 0, Depressed Count: 0
# Text: took a trip <tr> uh it was a mediterranean cruise oh my god that was the best time of my life, Positive Count: 1, Depressed Count: 0
# Text: oh god um being on that ship, Positive Count: 0, Depressed Count: 0
# Text: i felt electrifying uh fulfilled satisfied, Positive Count: 1, Depressed Count: 0
# Text: i felt like um, Positive Count: 1, Depressed Count: 0
# Text: i can do it, Positive Count: 0, Depressed Count: 0
# Text: and eh and it, Positive Count: 0, Depressed Count: 0
# Text: and i it just, Positive Count: 0, Depressed Count: 0
# Text: i moved past the fear and just said i'm doing this, Positive Count: 0, Depressed Count: 1
# Text: uh i'm in law school i'm xxx gonna i'm gonna be an attorney, Positive Count: 0, Depressed Count: 0
# Text: i've always wanted to be an attorney and it's been, Positive Count: 0, Depressed Count: 0
# Text: a long time coming, Positive Count: 0, Depressed Count: 0
# Text: oh my dream job is to have my own law firm my husband and i, Positive Count: 0, Depressed Count: 0
# Text: living in a beach community and, Positive Count: 0, Depressed Count: 0
# Text: our friends we know each other the community <communit> the community know <kn> we know each other it's a small town beach community, Positive Count: 0, Depressed Count: 0
# Text: having my own law firm working with my husband and, Positive Count: 0, Depressed Count: 0
# Text: providing legal services to people, Positive Count: 0, Depressed Count: 0
# Text: who are indigent, Positive Count: 0, Depressed Count: 1
# Text: uh i'm in the middle, Positive Count: 0, Depressed Count: 0
# Text: um it's one side of me that just like to withdraw and you know don't wanna be out in the front, Positive Count: 1, Depressed Count: 0
# Text: and it's another part of the personality is like oh no we're being in the front we're gonna be seen and eh we're <w> we're constantly in conflict, Positive Count: 1, Depressed Count: 1
# Text: yeah, Positive Count: 0, Depressed Count: 0
# Text: oh i get on my bike and ride my bike, Positive Count: 0, Depressed Count: 0
# Text: ooh it depends on what the situation is i need to control that, Positive Count: 0, Depressed Count: 0
# Text: mm not trouble but it made it has made people back up off of me, Positive Count: 0, Depressed Count: 1
# Text: oh god when was the last time i really had a argument i don't know it's been awhile um, Positive Count: 0, Depressed Count: 0
# Text: argument, Positive Count: 0, Depressed Count: 0
# Text: it's been a long time, Positive Count: 0, Depressed Count: 0
# Text: that i can't even remember, Positive Count: 0, Depressed Count: 0
# Text: oh god let's see, Positive Count: 0, Depressed Count: 0
# Text: <sigh> goodness, Positive Count: 1, Depressed Count: 0
# Text: mm, Positive Count: 0, Depressed Count: 0
# Text: mm, Positive Count: 0, Depressed Count: 0
# Text: oh just dealing with my siblings and my family and, Positive Count: 0, Depressed Count: 0
# Text: just trying to diffuse the situation and not get so heated and, Positive Count: 0, Depressed Count: 0
# Text: just remain cool and calm and collected, Positive Count: 2, Depressed Count: 0
# Text: oh when my mother passed years ago it was a conflict over her belongings and, Positive Count: 0, Depressed Count: 1
# Text: all that stuff and you know it was stressful time and everybody else <el> everybody's emotion was kinda high and, Positive Count: 0, Depressed Count: 1
# Text: arguing back and forth and i'm like i'm not doing that, Positive Count: 1, Depressed Count: 0
# Text: distant <laughter> and the reality <rea> i just i, Positive Count: 0, Depressed Count: 0
# Text: it's just amazing that these people no i shouldn't say these people, Positive Count: 1, Depressed Count: 0
# Text: that my we grew up in the family <fam> we grew up in the same household and then as we got older you know xxx god takes us on different path, Positive Count: 0, Depressed Count: 0
# Text: it's just like who are these people or did i grow up in a household with 'em why <wh> why are they and they may say the same thing about me i don't know i just like to have peaceful living honey, Positive Count: 2, Depressed Count: 0
# Text: pardon me, Positive Count: 1, Depressed Count: 0
# Text: oh god positive <po> um uh positive influences, Positive Count: 1, Depressed Count: 0
# Text: ooh college professors, Positive Count: 0, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: friends, Positive Count: 0, Depressed Count: 0
# Text: church members, Positive Count: 0, Depressed Count: 0
# Text: um people like that, Positive Count: 1, Depressed Count: 0
# Text: ooh god divorce, Positive Count: 0, Depressed Count: 0
# Text: should <s> should i continue with my education, Positive Count: 0, Depressed Count: 0
# Text: um when my mother was sick to be her primary caretaker put all my dreams and aspirations on hold, Positive Count: 1, Depressed Count: 1
# Text: um those have been some doozies, Positive Count: 0, Depressed Count: 0
# Text: well with my mom it's i you only have one mother and when it was over said and done i just wanted to do what was right according, Positive Count: 2, Depressed Count: 0
# Text: to what god would want me to do and i didn't wanna, Positive Count: 0, Depressed Count: 0
# Text: have any curses over my life but blessings 'cause the bible says honor thy parents, Positive Count: 1, Depressed Count: 1
# Text: my mother and father in all thy days so so you can live longer and i wanted, Positive Count: 0, Depressed Count: 0
# Text: blessings and not curses, Positive Count: 0, Depressed Count: 1
# Text: my marriage <laughter> my marriage, Positive Count: 0, Depressed Count: 0
# Text: ugh god that had such a negative influence on my life such a negative impact but in all that it, Positive Count: 0, Depressed Count: 2
# Text: taught me, Positive Count: 0, Depressed Count: 0
# Text: it made me who i am today, Positive Count: 0, Depressed Count: 0
# Text: and i have no animosity, Positive Count: 0, Depressed Count: 1
# Text: <sigh> lately it's been so difficult 'cause school and finals and midterms and all that is coming up, Positive Count: 0, Depressed Count: 1
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: sometimes rather difficult, Positive Count: 0, Depressed Count: 1
# Text: irritable annoyed, Positive Count: 0, Depressed Count: 2
# Text: grouchy, Positive Count: 0, Depressed Count: 1
# Text: well with all this stuff going on with the last week it's been real real real real real crazy, Positive Count: 1, Depressed Count: 1
# Text: god i pray i just i pray i pray i pray i pray lord i pray, Positive Count: 0, Depressed Count: 0
# Text: and the one thing that's keeping me kinda like grounded is going to church, Positive Count: 1, Depressed Count: 0
# Text: no never, Positive Count: 0, Depressed Count: 0
# Text: yeah when i went through that divorce um and my mother passed that i was really depressed, Positive Count: 0, Depressed Count: 1
# Text: fatigued tired uh xxx, Positive Count: 0, Depressed Count: 2
# Text: xxx, Positive Count: 0, Depressed Count: 0
# Text: xxx, Positive Count: 0, Depressed Count: 0
# Text: i no matter what i did i couldn't get any enjoyment just, Positive Count: 1, Depressed Count: 0
# Text: a feeling of emptiness and loneliness and isolation and, Positive Count: 0, Depressed Count: 3
# Text: shock trauma, Positive Count: 0, Depressed Count: 2
# Text: hard <har> it was very very very very difficult, Positive Count: 0, Depressed Count: 2
# Text: time um, Positive Count: 0, Depressed Count: 0
# Text: just time it just took time just to process to, Positive Count: 0, Depressed Count: 0
# Text: work its way through, Positive Count: 1, Depressed Count: 0
# Text: no no not at all, Positive Count: 0, Depressed Count: 0
# Text: just got busy with life stuff, Positive Count: 0, Depressed Count: 0
# Text: yeah i need somebody to talk to <laughter> yes, Positive Count: 0, Depressed Count: 0
# Text: oh god we i loved my therapist, Positive Count: 1, Depressed Count: 0
# Text: uh we talked things out and she gives me a different perspective and she just listened to me, Positive Count: 0, Depressed Count: 0
# Text: oh god, Positive Count: 0, Depressed Count: 0
# Text: well there's this guy at church and i really like him and he likes me and he throws kisses at me so, Positive Count: 3, Depressed Count: 0
# Text: and he's a, Positive Count: 0, Depressed Count: 0
# Text: oh outgoing um, Positive Count: 0, Depressed Count: 0
# Text: determined, Positive Count: 0, Depressed Count: 0
# Text: yeah trustworthy, Positive Count: 1, Depressed Count: 0
# Text: faithful and loyal, Positive Count: 2, Depressed Count: 0
# Text: oh god, Positive Count: 0, Depressed Count: 0
# Text: to be more patient, Positive Count: 1, Depressed Count: 0
# Text: um, Positive Count: 0, Depressed Count: 0
# Text: to be more patient, Positive Count: 1, Depressed Count: 0
# Text: oh my ex-husband he did that on a daily daily thing and i'm just so glad to get rid of him, Positive Count: 1, Depressed Count: 0
# Text: <sigh>, Positive Count: 0, Depressed Count: 0
# Text: know your worth, Positive Count: 1, Depressed Count: 0
# Text: your value, Positive Count: 0, Depressed Count: 0
# Text: and have high self-esteem, Positive Count: 0, Depressed Count: 0
# Text: well now with school in the library with tutors uh, Positive Count: 1, Depressed Count: 0
# Text: my outlet is riding my bike or either going swimming, Positive Count: 0, Depressed Count: 0
# Text: oh a friend of mine um had a c_d release party and me and a excuse me <yawn>, Positive Count: 0, Depressed Count: 1
# Text: ooh excuse me and me and another friend got together and we catered the party and it was so nice and they were so happy they were so thankful and grateful so thankful, Positive Count: 4, Depressed Count: 1
# Text: and then he invited me on stage 'cause he sings, Positive Count: 0, Depressed Count: 0
# Text: and, Positive Count: 0, Depressed Count: 0
# Text: i felt so when i got up on stage 'cause i like to sing but i'm so shy in front of people and they're judgmental and they might look at me, Positive Count: 1, Depressed Count: 0
# Text: and i got up on that stage and i just i'm like well this <th> is this how this feel this feels good <laughter>, Positive Count: 3, Depressed Count: 0
# Text: oh god i aw man, Positive Count: 0, Depressed Count: 0
# Text: oh my accomplishments <acc> my accomplishments um, Positive Count: 1, Depressed Count: 0
# Text: overcoming 'em one by one, Positive Count: 0, Depressed Count: 0
# Text: setting a goal and reaching 'em, Positive Count: 0, Depressed Count: 0
# Text: okay, Positive Count: 0, Depressed Count: 0
# Text: thank you honey <hon>, Positive Count: 1, Depressed Count: 0
# Text: bye, Positive Count: 0, Depressed Count: 0
#
# Label Distribution:
# label
# 0    10152
# 1     5154
# 2     1790
# Name: count, dtype: int64

# %%
# Define the Simple Neural Network model
embedding_dim = 200

model = Sequential([
    Embedding(max_words, embedding_dim, input_length=max_len),
    Flatten(),  # Flatten the output from the embedding layer
    Dense(128, activation='relu'),  # First dense layer
    Dropout(0.5),  # Dropout layer to prevent overfitting
    Dense(64, activation='relu'),   # Second dense layer
    Dropout(0.5),  # Another dropout layer
    Dense(3, activation='softmax')  # Output layer for 3 classes
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
print(model.summary())
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Train the model
model.fit(X_train_pad, y_train_cat, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices to a dense Tensor with 134000000 elements. This may consume a large amount of memory.
#   warnings.warn(
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 91s 263ms/step - accuracy: 0.6024 - loss: 0.9092 - val_accuracy: 0.8103 - val_loss: 0.5012
# Epoch 2/5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 90s 265ms/step - accuracy: 0.8357 - loss: 0.4626 - val_accuracy: 0.8534 - val_loss: 0.3747
# Epoch 3/5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 90s 263ms/step - accuracy: 0.8760 - loss: 0.3115 - val_accuracy: 0.8651 - val_loss: 0.3456
# Epoch 4/5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 97s 283ms/step - accuracy: 0.9037 - loss: 0.2395 - val_accuracy: 0.8187 - val_loss: 0.4851
# Epoch 5/5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 96s 279ms/step - accuracy: 0.9129 - loss: 0.2234 - val_accuracy: 0.8882 - val_loss: 0.4306

# %%
loss, accuracy = model.evaluate(X_test_pad, y_test_cat, verbose=0)
print(f"Test accuracy: {accuracy:.2f}")
# Out:
# Test accuracy: 0.88

# %%
def predict_sentiment(text):
    sequence = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(sequence, maxlen=max_len)
    prediction = model.predict(padded)
    predicted_class = np.argmax(prediction)
    confidence = prediction[0][predicted_class]
    
    if predicted_class == 2:
        return f"The user might be depressed. Confidence: {confidence:.2f}"
    elif predicted_class == 1:
        return f"The user is in a positive mood. Confidence: {confidence:.2f}"
    else:
        return f"The user is in a neutral/negative mood. Confidence: {confidence:.2f}"

# Test the model with some example conversations
examples = [
    "I feel so hopeless and sad all the time.",
    "I'm excited about my new job and looking forward to the future.",
    "I don't know if life is worth living anymore.",
    "I had a great day with my friends and family.",
    "This weather is terrible, and I'm having a bad day.",
    "I want to kill myself",
    "I'm feeling a bit down today, but I'm sure things will get better.",
     "I feel like nothing is going right for me today.",
"I just can't seem to focus on anything right now.",
"I'm really struggling to keep up, and it's frustrating.",
"Today feels like a complete waste; I can’t get anything done.",
"I'm overwhelmed, and it's dragging my mood down.",
"I feel stuck in a rut, and it’s wearing me out.",
"Everything I touch seems to go wrong today.",
"I'm feeling really down and unmotivated.",
"I just don't have the energy for anything today.",
"It's one of those days where nothing feels worth the effort."
]

for example in examples:
    print(f"Text: {example}")
    print(f"Prediction: {predict_sentiment(example)}\n")

# Save the model
model.save('sentiment_cnn_model.h5')

# Save the tokenizer
import pickle
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

print("Model and tokenizer saved successfully.")

# To load the model and tokenizer later, you can use:
# loaded_model = tf.keras.models.load_model('sentiment_cnn_model.h5')
# with open('tokenizer.pickle', 'rb') as handle:
#     loaded_tokenizer = pickle.load(handle)
# Out:
# Text: I feel so hopeless and sad all the time.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 0.93
#
# Text: I'm excited about my new job and looking forward to the future.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 1.00
#
# Text: I don't know if life is worth living anymore.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Prediction: The user might be depressed. Confidence: 0.57
#
# Text: I had a great day with my friends and family.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Prediction: The user is in a positive mood. Confidence: 0.95
#
# Text: This weather is terrible, and I'm having a bad day.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Prediction: The user is in a positive mood. Confidence: 0.82
#
# Text: I want to kill myself
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 0.96
#
# Text: I'm feeling a bit down today, but I'm sure things will get better.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Prediction: The user is in a positive mood. Confidence: 1.00
#
# Text: I feel like nothing is going right for me today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Prediction: The user is in a positive mood. Confidence: 1.00
#
# Text: I just can't seem to focus on anything right now.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Prediction: The user is in a positive mood. Confidence: 0.99
#
# Text: I'm really struggling to keep up, and it's frustrating.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Prediction: The user might be depressed. Confidence: 0.64
#
# Text: Today feels like a complete waste; I can’t get anything done.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Prediction: The user is in a positive mood. Confidence: 0.98
#
# Text: I'm overwhelmed, and it's dragging my mood down.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Prediction: The user might be depressed. Confidence: 0.62
#
# Text: I feel stuck in a rut, and it’s wearing me out.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Prediction: The user might be depressed. Confidence: 0.66
#
# Text: Everything I touch seems to go wrong today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 1.00
#
# Text: I'm feeling really down and unmotivated.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 0.51
#
# Text: I just don't have the energy for anything today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 0.98
#
# Text: It's one of those days where nothing feels worth the effort.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Prediction: The user might be depressed. Confidence: 0.52
#
# Model and tokenizer saved successfully.

# %%
some more example

# %%
def predict_sentiment(text):
    sequence = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(sequence, maxlen=max_len)
    prediction = model.predict(padded)
    predicted_class = np.argmax(prediction)
    confidence = prediction[0][predicted_class]
    
    if predicted_class == 2:
        return f"The user might be depressed. Confidence: {confidence:.2f}"
    elif predicted_class == 1:
        return f"The user is in a positive mood. Confidence: {confidence:.2f}"
    else:
        return f"The user is in a neutral/negative mood. Confidence: {confidence:.2f}"
examples = [
        "I feel so hopeless and sad all the time.",
        "I'm excited about my new job and looking forward to the future.",
        "I don't know if life is worth living anymore.",
        "I had a great day with my friends and family.",
        "This weather is terrible, and I'm having a bad day.",
        "I'm feeling a bit down today, but I'm sure things will get better.",
        "I'm really proud of what I accomplished today.",
        "Sometimes I wonder if I'll ever find my way.",
        "I had a productive meeting, but I still have a lot on my plate.",
        "Today was just another ordinary day.",
        "I'm thrilled about my upcoming vacation!",
        "I'm feeling overwhelmed by everything that’s happening.",
        "I'm content with where I am in life right now.",
        "I can't shake off this feeling of dread.",
        "I had a fun time at the park with my friends last weekend."
    ]

for example in examples:
    print(f"Text: {example}")
    print(f"Prediction: {predict_sentiment(example)}\n")

# Save the model
model.save('sentiment_cnn_model.h5')

# Save the tokenizer
import pickle
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

print("Model and tokenizer saved successfully.")
# Out:
# Text: I feel so hopeless and sad all the time.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 0.93
#
# Text: I'm excited about my new job and looking forward to the future.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 1.00
#
# Text: I don't know if life is worth living anymore.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Prediction: The user might be depressed. Confidence: 0.57
#
# Text: I had a great day with my friends and family.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Prediction: The user is in a positive mood. Confidence: 0.95
#
# Text: This weather is terrible, and I'm having a bad day.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Prediction: The user is in a positive mood. Confidence: 0.82
#
# Text: I'm feeling a bit down today, but I'm sure things will get better.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Prediction: The user is in a positive mood. Confidence: 1.00
#
# Text: I'm really proud of what I accomplished today.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Prediction: The user is in a positive mood. Confidence: 1.00
#
# Text: Sometimes I wonder if I'll ever find my way.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Prediction: The user might be depressed. Confidence: 0.64
#
# Text: I had a productive meeting, but I still have a lot on my plate.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Prediction: The user is in a positive mood. Confidence: 0.49
#
# Text: Today was just another ordinary day.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 1.00
#
# Text: I'm thrilled about my upcoming vacation!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Prediction: The user might be depressed. Confidence: 0.65
#
# Text: I'm feeling overwhelmed by everything that’s happening.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 0.50
#
# Text: I'm content with where I am in life right now.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Prediction: The user is in a positive mood. Confidence: 1.00
#
# Text: I can't shake off this feeling of dread.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Prediction: The user is in a neutral/negative mood. Confidence: 0.97
#
# Text: I had a fun time at the park with my friends last weekend.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Prediction: The user is in a positive mood. Confidence: 0.79
#
# Model and tokenizer saved successfully.
